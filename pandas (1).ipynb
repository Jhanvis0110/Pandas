# %% [markdown]
# # Structured data
#
# >Pandas
#
# >Pyspark

# %% [markdown]
# # PANDAS :  Panel Data
#
# * Definition of pandas --> data of individual,organisation or domain generated data over a period of time called Panel Data.
# * Pandas is third party software/library.
# * the structured data which has heading of its every column.
# * it works on reading structured data.
# * pandas(2008)

# %% [markdown]
# # How many type of structure data we have?
#
# >Individual
#
#       particular data
#
# >Organisation data
#
#      company's data which is generating overa period of time
#
# >Domain data
#
#      Telecom services company's performance data

# %% [markdown]
# # Data:
#    the data which pandas read:--
#
#     excel(semi structured data)
#
#     csv(plain text file. it uses excel to show in tabular file)
#
#     database table(pure structred data)
#
#     html table(semi structured data)
#
#     xml table(semi structured data)
#
#     etc....

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# %pip install xlrd

# %%
# %pip install openpyxl
# Out:
# ...
#
# ...
#      -------------------------------------- 242.1/242.1 kB 1.3 MB/s eta 0:00:00
# ...

# %%
pd.read_excel("C:/Users\Dell\Desktop\Book11.xlsx")
# Out:
#    sn     name branch
# 0   1  Krishna    MCA
# 1   2    Rahul    BCA
# 2   3   Roshan     CS

# %%
pd.read_excel("C:\\Users\Dell\Desktop\Book11.xlsx",sheet_name="Sheet2")
# Out:
#         sn    name branch
# 0  Krishna       1    MCA
# 1        2   Rahul    BCA
# 2        3  Roshan     CS

# %%
df=pd.read_excel("C:\\Users\Dell\Desktop\Book11.xlsx",sheet_name=["Sheet1","Sheet2"])
df
# Out:
# {'Sheet1':    sn     name branch
#  0   1  Krishna    MCA
#  1   2    Rahul    BCA
#  2   3   Roshan     CS,
#  'Sheet2':         sn    name branch
#  0  Krishna       1    MCA
#  1        2   Rahul    BCA
#  2        3  Roshan     CS}

# %%
df["Sheet1"]
# Out:
#    sn     name branch
# 0   1  Krishna    MCA
# 1   2    Rahul    BCA
# 2   3   Roshan     CS

# %%
df["Sheet2"]
# Out:
#         sn    name branch
# 0  Krishna       1    MCA
# 1        2   Rahul    BCA
# 2        3  Roshan     CS

# %%
df=pd.read_excel("C:\\Users\Dell\Desktop\Book11.xlsx",sheet_name=0)
df
# Out:
#    sn     name branch
# 0   1  Krishna    MCA
# 1   2    Rahul    BCA
# 2   3   Roshan     CS

# %%
pd.read_excel(r"C:/Users\Dell\Desktop\Book11.xlsx")
# Out:
#    sn     name branch
# 0   1  Krishna    MCA
# 1   2    Rahul    BCA
# 2   3   Roshan     CS

# %%
df=pd.read_csv(r"C:\Users\Dell\Desktop\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=pd.read_excel("C:/Users\Dell\Desktop\weather.xlsx")
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
# analysics khata h jo bi data tum uthate ho kuch report banane k liy toh us data ka prepare hona phle zaruri .prepare means koi bi aisa value ni hona chahie jo missing ho warna wo proper analysics report ni dega wo kuchna kuch prblm dega toh ya toh in NaN value ko remove krdo ya aise value dalo jo genuine ho

# %%
(32+28)/2
# Out:
# 30.0

# %%
df.dropna()  # NaN data is deleted it makes copy actual datafrma df not change
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.temperature
# Out:
# 0    32.0
# 1     NaN
# 2    28.0
# 3     NaN
# 4    32.0
# 5     NaN
# 6     NaN
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %%
df['temperature'] #for string
# Out:
# 0    32.0
# 1     NaN
# 2    28.0
# 3     NaN
# 4    32.0
# 5     NaN
# 6     NaN
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %%
d=df.temperature.mean() #mean is a method. bydefault axis is none

# %%
df.temperature.fillna(d)
# Out:
# 0    32.000000
# 1    32.666667
# 2    28.000000
# 3    32.666667
# 4    32.000000
# 5    32.666667
# 6    32.666667
# 7    34.000000
# 8    40.000000
# 9    30.000000
# Name: temperature, dtype: float64

# %%
df.temperature.fillna(d,inplace=True) 
df
#dataframe me se temperature column pr jo bi null value h usko fill kro df.temperature.mean() se inplace=true krke jo bi fill kroge wo permanent change krege df me jaha bi NaN h
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        NaN   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        NaN   Rain
# 5 2022-01-06    32.666667        NaN  Sunny
# 6 2022-01-07    32.666667        NaN    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
df.windspeed.fillna(df.windspeed.median(),inplace=False)
# Out:
# 0     6.0
# 1     9.0
# 2     8.5
# 3     7.0
# 4     8.5
# 5     8.5
# 6     8.5
# 7     8.0
# 8    12.0
# 9    10.0
# Name: windspeed, dtype: float64

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        NaN   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        NaN   Rain
# 5 2022-01-06    32.666667        NaN  Sunny
# 6 2022-01-07    32.666667        NaN    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
df.windspeed.fillna(df.windspeed.median(),inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
# data lost na ho isly humne mean (statitcs) ka use krte

# %% [raw]
# mode-->highest occuring value. usse sabi NaN fill krdege jo catalogical aur numerical pr chalta h

# %%
df.event.mode()   #we get the mode sunny but it is object we want value.
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
df.event.mode().values #here we get the list
# Out:
# array(['Sunny'], dtype=object)

# %%
df.event.mode().values[0] #after putting index value we get the value
# Out:
# 'Sunny'

# %%
df.event.fillna(df.event.mode().values[0],inplace=True)  #getting list value convert into integer value
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0  Sunny
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5  Sunny
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
df.event.mode()
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
df.event.fillna('Sunny',inplace=True)
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0  Sunny
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5  Sunny
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
list(df.event.mode().values[0])
# Out:
# ['S', 'u', 'n', 'n', 'y']

# %%
[""+i for i in df.event.mode().values[0]]
# Out:
# ['S', 'u', 'n', 'n', 'y']

# %%
's'+'u'
# Out:
# 'su'

# %% [markdown]
# # Forward Filling:

# %%
df=pd.read_excel("C:/Users\Dell\Desktop\weather.xlsx")

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0  Sunny
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5  Sunny
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.temperature.ffill(inplace=True)   # ffill--> forward filling it is a method

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04         28.0        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06         32.0        NaN  Sunny
# 6 2022-01-07         32.0        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.ffill()    
# it will do changes in one tym but temporary for permanent change put inplace=true in bracket
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        9.0   Snow
# 3 2022-01-04         28.0        7.0   Snow
# 4 2022-01-05         32.0        7.0   Rain
# 5 2022-01-06         32.0        7.0  Sunny
# 6 2022-01-07         32.0        7.0  Sunny
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %% [markdown]
# # Backward Filling

# %%
df=pd.read_excel("C:/Users\Dell\Desktop\weather.xlsx")

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.temperature.bfill()
# Out:
# 0    32.0
# 1    28.0
# 2    28.0
# 3    32.0
# 4    32.0
# 5    34.0
# 6    34.0
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %%
df.temperature.backfill(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04         32.0        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06         34.0        NaN  Sunny
# 6 2022-01-07         34.0        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.event.bfill(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04         32.0        7.0   Rain
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06         34.0        NaN  Sunny
# 6 2022-01-07         34.0        NaN  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.windspeed.ffill(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 2 2022-01-03         28.0        9.0   Snow
# 3 2022-01-04         32.0        7.0   Rain
# 4 2022-01-05         32.0        7.0   Rain
# 5 2022-01-06         34.0        7.0  Sunny
# 6 2022-01-07         34.0        7.0  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
# drop_duplicate is used to remove duplicate data

# %%
df.drop_duplicates()
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 2 2022-01-03         28.0        9.0   Snow
# 3 2022-01-04         32.0        7.0   Rain
# 4 2022-01-05         32.0        7.0   Rain
# 5 2022-01-06         34.0        7.0  Sunny
# 6 2022-01-07         34.0        7.0  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.temperature.drop_duplicates(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 2 2022-01-03         28.0        9.0   Snow
# 3 2022-01-04         32.0        7.0   Rain
# 4 2022-01-05         32.0        7.0   Rain
# 5 2022-01-06         34.0        7.0  Sunny
# 6 2022-01-07         34.0        7.0  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df.temperature.drop_duplicates()
# Out:
# 0    32.0
# 1    28.0
# 5    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %%
df.drop_duplicates(subset='temperature')
# Out:
#         date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         28.0        9.0  Sunny
# 5 2022-01-06         34.0        7.0  Sunny
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
info=pd.DataFrame({'name':['Krishna','Rahul','Mohan','Chintu','Pintu','Mohan','Chintu','Pintu'],
            'contact':[9878563322,7384962468,9068567543,8700100348,8435665430,9068567543,8700100348,8435665430]})

# %%
info
# Out:
#       name     contact
# 0  Krishna  9878563322
# 1    Rahul  7384962468
# 2    Mohan  9068567543
# 3   Chintu  8700100348
# 4    Pintu  8435665430
# 5    Mohan  9068567543
# 6   Chintu  8700100348
# 7    Pintu  8435665430

# %%
info.drop_duplicates(subset='contact')
# Out:
#       name     contact
# 0  Krishna  9878563322
# 1    Rahul  7384962468
# 2    Mohan  9068567543
# 3   Chintu  8700100348
# 4    Pintu  8435665430

# %%
info=pd.DataFrame({'name':['Krishna','Rahul','Mohan','Chintu','Pintu','Saumya','Chintu','Pintu'],
            'contact':[9878563322,7384962468,9068567543,8700100348,8435665430,9068567543,8700100348,8435665430]})

# %%
info
# Out:
#       name     contact
# 0  Krishna  9878563322
# 1    Rahul  7384962468
# 2    Mohan  9068567543
# 3   Chintu  8700100348
# 4    Pintu  8435665430
# 5   Saumya  9068567543
# 6   Chintu  8700100348
# 7    Pintu  8435665430

# %%
info.drop_duplicates(subset=['name','contact'])
# Out:
#       name     contact
# 0  Krishna  9878563322
# 1    Rahul  7384962468
# 2    Mohan  9068567543
# 3   Chintu  8700100348
# 4    Pintu  8435665430
# 5   Saumya  9068567543

# %%
restra=pd.read_csv("tips.csv") #table is in 2D array

# %%
restra
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Correlation--> corr():
#
# ek column dusre column pr kitna dependent h usse niklne k liy use krte       correlation. it work on numerical data. range of corr data is from -1 to 0 to 1
#
# Analysics of Variance--> anova(): yeh humre categorical data me bi relation niklne k kosish       krta h. cataegorical means jo kishe specific class se belong krta ho na ki sirf alphabetical
# Chaisquare correlation--> mostly used in prediction.

# %% [raw]
# Interview Question:
# Q--What is diff b/w cataegorical value and discrite value?
# A--Cataegorical value wo hote jo kishe class se belong kre. agar koi cataegorical value h male,female toh usse hum 0,1 ki form me kr skte kyuki hume pta h ki 2 he clss h iski.
#    Discrite value jo humsha change hote rhe.

# %% [raw]
# -1 means kuch bi related ni h  agar jada value -ve aate toh delte krdete
# 0 means kuch related h
# 1 means sab related h

# %%
restra.corr() 
# here in o/p 1 means 100% related bcoz it is similar nd 0 means 0% related after point the no i.e,67%
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15836\288171620.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   restra.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
restra.sex.unique()  # string ko obj ni bolte
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
restra.smoker.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
restra['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
restra['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
restra.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
restra.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
restra.sex.map({'Female':0,'Male':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 239    1
# 240    0
# 241    1
# 242    1
# 243    0
# Name: sex, Length: 244, dtype: int64

# %%
restra.sex=restra.sex.map({'Female':0,'Male':1})

# %%
restra
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01    0     No   Sun  Dinner     2
# 1         10.34  1.66    1     No   Sun  Dinner     3
# 2         21.01  3.50    1     No   Sun  Dinner     3
# 3         23.68  3.31    1     No   Sun  Dinner     2
# 4         24.59  3.61    0     No   Sun  Dinner     4
# ..          ...   ...  ...    ...   ...     ...   ...
# 239       29.03  5.92    1     No   Sat  Dinner     3
# 240       27.18  2.00    0    Yes   Sat  Dinner     2
# 241       22.67  2.00    1    Yes   Sat  Dinner     2
# 242       17.82  1.75    1     No   Sat  Dinner     2
# 243       18.78  3.00    0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra.smoker.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
restra.smoker=restra.smoker.map({'No':0,'Yes':1})

# %%
restra
# Out:
#      total_bill   tip  sex  smoker   day    time  size
# 0         16.99  1.01    0       0   Sun  Dinner     2
# 1         10.34  1.66    1       0   Sun  Dinner     3
# 2         21.01  3.50    1       0   Sun  Dinner     3
# 3         23.68  3.31    1       0   Sun  Dinner     2
# 4         24.59  3.61    0       0   Sun  Dinner     4
# ..          ...   ...  ...     ...   ...     ...   ...
# 239       29.03  5.92    1       0   Sat  Dinner     3
# 240       27.18  2.00    0       1   Sat  Dinner     2
# 241       22.67  2.00    1       1   Sat  Dinner     2
# 242       17.82  1.75    1       0   Sat  Dinner     2
# 243       18.78  3.00    0       0  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
restra.day=restra.day.map({'Sun':0,'Sat':1,'Thur':2,'Fri':3})

# %%
restra
# Out:
#      total_bill   tip  sex  smoker  day    time  size
# 0         16.99  1.01    0       0    0  Dinner     2
# 1         10.34  1.66    1       0    0  Dinner     3
# 2         21.01  3.50    1       0    0  Dinner     3
# 3         23.68  3.31    1       0    0  Dinner     2
# 4         24.59  3.61    0       0    0  Dinner     4
# ..          ...   ...  ...     ...  ...     ...   ...
# 239       29.03  5.92    1       0    1  Dinner     3
# 240       27.18  2.00    0       1    1  Dinner     2
# 241       22.67  2.00    1       1    1  Dinner     2
# 242       17.82  1.75    1       0    1  Dinner     2
# 243       18.78  3.00    0       0    2  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
restra.time=restra.time.map({'Dinner':0,'Lunch':1})

# %%
restra
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     0     2
# 1         10.34  1.66    1       0    0     0     3
# 2         21.01  3.50    1       0    0     0     3
# 3         23.68  3.31    1       0    0     0     2
# 4         24.59  3.61    0       0    0     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    2     0     2
#
# [244 rows x 7 columns]

# %%
restra.corr()
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721 -0.175312 -0.183118
# tip           0.675734  1.000000  0.088862  0.005929 -0.138947 -0.121629
# sex           0.144877  0.088862  1.000000  0.002816 -0.215374 -0.205231
# smoker        0.085721  0.005929  0.002816  1.000000  0.170818 -0.054921
# day          -0.175312 -0.138947 -0.215374  0.170818  1.000000  0.670470
# time         -0.183118 -0.121629 -0.205231 -0.054921  0.670470  1.000000
# size          0.598315  0.489299  0.086195 -0.133178 -0.211750 -0.103411
#
#                 size
# total_bill  0.598315
# tip         0.489299
# sex         0.086195
# smoker     -0.133178
# day        -0.211750
# time       -0.103411
# size        1.000000

# %%
restra
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     0     2
# 1         10.34  1.66    1       0    0     0     3
# 2         21.01  3.50    1       0    0     0     3
# 3         23.68  3.31    1       0    0     0     2
# 4         24.59  3.61    0       0    0     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    2     0     2
#
# [244 rows x 7 columns]

# %%
restra[restra.sex==1]
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 1         10.34  1.66    1       0    0     0     3
# 2         21.01  3.50    1       0    0     0     3
# 3         23.68  3.31    1       0    0     0     2
# 5         25.29  4.71    1       0    0     0     4
# 6          8.77  2.00    1       0    0     0     2
# ..          ...   ...  ...     ...  ...   ...   ...
# 236       12.60  1.00    1       1    1     0     2
# 237       32.83  1.17    1       1    1     0     2
# 239       29.03  5.92    1       0    1     0     3
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
#
# [157 rows x 7 columns]

# %%
restra[(restra.sex==1)&(restra.smoker==1)]
# Out:
#      total_bill    tip  sex  smoker  day  time  size
# 56        38.01   3.00    1       1    1     0     4
# 58        11.24   1.76    1       1    1     0     2
# 60        20.29   3.21    1       1    1     0     2
# 61        13.81   2.00    1       1    1     0     2
# 62        11.02   1.98    1       1    1     0     2
# 63        18.29   3.76    1       1    1     0     4
# 69        15.01   2.09    1       1    1     0     2
# 76        17.92   3.08    1       1    1     0     2
# 80        19.44   3.00    1       1    2     1     2
# 83        32.68   5.00    1       1    2     1     2
# 90        28.97   3.00    1       1    3     0     2
# 95        40.17   4.73    1       1    3     0     4
# 96        27.28   4.00    1       1    3     0     2
# 97        12.03   1.50    1       1    3     0     2
# 98        21.01   3.00    1       1    3     0     2
# 105       15.36   1.64    1       1    1     0     2
# 106       20.49   4.06    1       1    1     0     2
# ...

# %%
restra[(restra.sex==1)&(restra.smoker==1)].shape
# Out:
# (60, 7)

# %%
restra[restra.sex==0]
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     0     2
# 4         24.59  3.61    0       0    0     0     4
# 11        35.26  5.00    0       0    0     0     4
# 14        14.83  3.02    0       0    0     0     2
# 16        10.33  1.67    0       0    0     0     3
# ..          ...   ...  ...     ...  ...   ...   ...
# 226       10.09  2.00    0       1    3     1     2
# 229       22.12  2.88    0       1    1     0     2
# 238       35.83  4.67    0       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 243       18.78  3.00    0       0    2     0     2
#
# [87 rows x 7 columns]

# %%
restra[(restra.sex==0)&(restra.smoker==1)].shape
# Out:
# (33, 7)

# %%
restra[(restra.sex==0)].shape
# Out:
# (87, 7)

# %%
(60/157)*100
# Out:
# 38.21656050955414

# %%
(33/87)*100
# Out:
# 37.93103448275862

# %%
restra.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sum(restra.total_bill)
# Out:
# 4827.770000000001

# %%
import numpy as np

# %%
np.sum(restra.total_bill)
# Out:
# 4827.77

# %%
import math

# %%
math.fsum(restra.total_bill)
# Out:
# 4827.7699999999995

# %%
restra[(restra.sex==0)&(restra.day==1)&(restra.time==0)].shape[0]
# Out:
# 28

# %%
restra[(restra.sex==1)&(restra.day==1)&(restra.time==0)].shape[0]
# Out:
# 59

# %%
sum(restra.tip[restra.sex==0])
# Out:
# 246.51

# %%
sum(restra.tip[restra.sex==1])
# Out:
# 485.0700000000001

# %%
max(restra.tip[restra.sex==1])
# Out:
# 10.0

# %%
max(restra.tip[restra.sex==0])
# Out:
# 6.5

# %%
min(restra.tip[restra.sex==0])
# Out:
# 1.0

# %%
min(restra.tip[restra.sex==1])
# Out:
# 1.0

# %%
max(restra.tip[restra.sex==1])
# Out:
# 10.0

# %%
restra[(restra.tip==10)]
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 170       50.81  10.0    1       1    1     0     3

# %%
restra[(restra.tip==max(restra.tip[restra.sex==0]))]
# Out:
#      total_bill  tip  sex  smoker  day  time  size
# 183       23.17  6.5    1       1    0     0     4
# 214       28.17  6.5    0       1    1     0     3

# %%
restra
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     0     2
# 1         10.34  1.66    1       0    0     0     3
# 2         21.01  3.50    1       0    0     0     3
# 3         23.68  3.31    1       0    0     0     2
# 4         24.59  3.61    0       0    0     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    2     0     2
#
# [244 rows x 7 columns]

# %%
def assign(restra):
   # a=rest.day.unique()    #[sun,sat,thur,fri]
    b=[]
    for i in rest.day:
        if i=='Sun':
            b.append(0)
        elif i=='Sat':
            b.append(1)
        elif i=='Thur':
            b.append(2)
        elif i=='Fri':
            b.append(3)
        else:
            pass
        b=restra.day
    return

# %%
restra
# Out:
#      total_bill   tip  sex  smoker   day    time  size
# 0         16.99  1.01    0       0   Sun  Dinner     2
# 1         10.34  1.66    1       0   Sun  Dinner     3
# 2         21.01  3.50    1       0   Sun  Dinner     3
# 3         23.68  3.31    1       0   Sun  Dinner     2
# 4         24.59  3.61    0       0   Sun  Dinner     4
# ..          ...   ...  ...     ...   ...     ...   ...
# 239       29.03  5.92    1       0   Sat  Dinner     3
# 240       27.18  2.00    0       1   Sat  Dinner     2
# 241       22.67  2.00    1       1   Sat  Dinner     2
# 242       17.82  1.75    1       0   Sat  Dinner     2
# 243       18.78  3.00    0       0  Thur  Dinner     2
#
# [244 rows x 7 columns]
